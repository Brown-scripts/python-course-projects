# %% [markdown]
# # NAME:BROWN KATHLEEN NICOLE

# %% [markdown]
# # ID:10980830

# %% [markdown]
# # SENG 207:PROGRAMMING FOR ENGINEERS

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
# 4                   11                    34   0.9978  3.51       0.56
#
#    Alcohol  Quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## Removing null values:
# ### We do not have accurate information or records to input,so null values have to be eliminated to ensure that the analysis is done on an accurate dataset

# %%
df.isnull().sum()
# Out:
# Fixed Acidity           0
# Volatile Acidity        0
# Citric Acid             0
# Residual Sugar          0
# Chlorides               0
# Free Sulfur Dioxide     0
# Total Sulfur Dioxide    0
# Density                 0
# pH                      0
# Sulphates               0
# Alcohol                 0
# Quality                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fixed Acidity         5 non-null      float64
#  1   Volatile Acidity      5 non-null      float64
#  2   Citric Acid           5 non-null      float64
#  3   Residual Sugar        5 non-null      float64
#  4   Chlorides             5 non-null      float64
#  5   Free Sulfur Dioxide   5 non-null      int64
#  6   Total Sulfur Dioxide  5 non-null      int64
#  7   Density               5 non-null      float64
#  8   pH                    5 non-null      float64
#  9   Sulphates             5 non-null      float64
#  10  Alcohol               5 non-null      float64
#  11  Quality               5 non-null      int64
# dtypes: float64(9), int64(3)
# memory usage: 608.0 bytes

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#        Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  \
# count       4.000000           4.00000     4.000000        4.000000
# mean        8.550000           0.65500     0.150000        2.175000
# std         1.776701           0.26096     0.273983        0.340343
# min         7.400000           0.28000     0.000000        1.900000
# 25%         7.700000           0.59500     0.000000        1.900000
# 50%         7.800000           0.73000     0.020000        2.100000
# 75%         8.650000           0.79000     0.170000        2.375000
# max        11.200000           0.88000     0.560000        2.600000
#
#        Chlorides  Free Sulfur Dioxide  Total Sulfur Dioxide   Density  \
# count   4.000000             4.000000              4.000000  4.000000
# mean    0.085250            17.000000             53.750000  0.997400
# std     0.011529             5.887841             14.198005  0.000589
# min     0.075000            11.000000             34.000000  0.996800
# ...

# %%
df['Fixed Acidity'].describe()
# Out:
# count     4.000000
# mean      8.550000
# std       1.776701
# min       7.400000
# 25%       7.700000
# 50%       7.800000
# 75%       8.650000
# max      11.200000
# Name: Fixed Acidity, dtype: float64

# %%
df['Volatile Acidity'].describe()
# Out:
# count    4.00000
# mean     0.65500
# std      0.26096
# min      0.28000
# 25%      0.59500
# 50%      0.73000
# 75%      0.79000
# max      0.88000
# Name: Volatile Acidity, dtype: float64

# %%
df['Citric Acid'].describe()
# Out:
# count    4.000000
# mean     0.150000
# std      0.273983
# min      0.000000
# 25%      0.000000
# 50%      0.020000
# 75%      0.170000
# max      0.560000
# Name: Citric Acid, dtype: float64

# %%
df['Residual Sugar'].describe()
# Out:
# count    4.000000
# mean     2.175000
# std      0.340343
# min      1.900000
# 25%      1.900000
# 50%      2.100000
# 75%      2.375000
# max      2.600000
# Name: Residual Sugar, dtype: float64

# %%
df['Chlorides'].describe()
# Out:
# count    4.000000
# mean     0.085250
# std      0.011529
# min      0.075000
# 25%      0.075750
# 50%      0.084000
# 75%      0.093500
# max      0.098000
# Name: Chlorides, dtype: float64

# %%
df['Free Sulfur Dioxide'].describe()
# Out:
# count     4.000000
# mean     17.000000
# std       5.887841
# min      11.000000
# 25%      14.000000
# 50%      16.000000
# 75%      19.000000
# max      25.000000
# Name: Free Sulfur Dioxide, dtype: float64

# %%
df['Total Sulfur Dioxide'].describe()
# Out:
# count     4.000000
# mean     53.750000
# std      14.198005
# min      34.000000
# 25%      49.000000
# 50%      57.000000
# 75%      61.750000
# max      67.000000
# Name: Total Sulfur Dioxide, dtype: float64

# %%
df['Density'].describe()
# Out:
# count    4.000000
# mean     0.997400
# std      0.000589
# min      0.996800
# 25%      0.996950
# 50%      0.997400
# 75%      0.997850
# max      0.998000
# Name: Density, dtype: float64

# %%
df['pH'].describe()
# Out:
# count    4.000000
# mean     3.282500
# std      0.157136
# min      3.160000
# 25%      3.190000
# 50%      3.230000
# 75%      3.322500
# max      3.510000
# Name: pH, dtype: float64

# %%
df['Sulphates'].describe()
# Out:
# count    4.000000
# mean     0.617500
# std      0.056789
# min      0.560000
# 25%      0.575000
# 50%      0.615000
# 75%      0.657500
# max      0.680000
# Name: Sulphates, dtype: float64

# %%
df['Alcohol'].describe()
# Out:
# count    4.0
# mean     9.7
# std      0.2
# min      9.4
# 25%      9.7
# 50%      9.8
# 75%      9.8
# max      9.8
# Name: Alcohol, dtype: float64

# %%
df['Quality'].describe()
# Out:
# count    4.00
# mean     5.25
# std      0.50
# min      5.00
# 25%      5.00
# 50%      5.00
# 75%      5.25
# max      6.00
# Name: Quality, dtype: float64

# %%
df
# Out:
#    Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  Chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
#
#    Free Sulfur Dioxide  Total Sulfur Dioxide  Density    pH  Sulphates  \
# 0                   11                    34   0.9978  3.51       0.56
# 1                   25                    67   0.9968  3.20       0.68
# 2                   15                    54   0.9970  3.26       0.65
# 3                   17                    60   0.9980  3.16       0.58
#
#    Alcohol  Quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fixed Acidity         4 non-null      float64
#  1   Volatile Acidity      4 non-null      float64
#  2   Citric Acid           4 non-null      float64
#  3   Residual Sugar        4 non-null      float64
#  4   Chlorides             4 non-null      float64
#  5   Free Sulfur Dioxide   4 non-null      int64
#  6   Total Sulfur Dioxide  4 non-null      int64
#  7   Density               4 non-null      float64
#  8   pH                    4 non-null      float64
#  9   Sulphates             4 non-null      float64
#  10  Alcohol               4 non-null      float64
#  11  Quality               4 non-null      int64
# dtypes: float64(9), int64(3)
# memory usage: 416.0 bytes

# %%
df=df.rename(columns={'Fixed Acidity':'fixed_acidity','Volatile Acidity':'volatile_acidity','Citric Acid':'citric_acid','Residual Sugar':'residual_sugar','Free Sulfur Dioxide':'free_sulfur_dioxide','Total Sulfur Dioxide':'total_sulfur_dioxide'})

# %%
df.isnull()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  Chlorides  \
# 0          False             False        False           False      False
# 1          False             False        False           False      False
# 2          False             False        False           False      False
# 3          False             False        False           False      False
#
#    free_sulfur_dioxide  total_sulfur_dioxide  Density     pH  Sulphates  \
# 0                False                 False    False  False      False
# 1                False                 False    False  False      False
# 2                False                 False    False  False      False
# 3                False                 False    False  False      False
#
#    Alcohol  Quality
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False

# %%
dfFill=df.mean()

# %%
dfFill
# Out:
# fixed_acidity            8.55000
# volatile_acidity         0.65500
# citric_acid              0.15000
# residual_sugar           2.17500
# Chlorides                0.08525
# free_sulfur_dioxide     17.00000
# total_sulfur_dioxide    53.75000
# Density                  0.99740
# pH                       3.28250
# Sulphates                0.61750
# Alcohol                  9.70000
# Quality                  5.25000
# dtype: float64

# %%
df=df.fillna(dfFill).drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         4 non-null      float64
#  1   volatile_acidity      4 non-null      float64
#  2   citric_acid           4 non-null      float64
#  3   residual_sugar        4 non-null      float64
#  4   Chlorides             4 non-null      float64
#  5   free_sulfur_dioxide   4 non-null      int64
#  6   total_sulfur_dioxide  4 non-null      int64
#  7   Density               4 non-null      float64
#  8   pH                    4 non-null      float64
#  9   Sulphates             4 non-null      float64
#  10  Alcohol               4 non-null      float64
#  11  Quality               4 non-null      int64
# dtypes: float64(9), int64(3)
# memory usage: 416.0 bytes

# %%
df['fixed_acidity'].hist(bins=10, color='black')
plt.show()

# %%
df['volatile_acidity'].hist(bins=10)
plt.show()

# %%
df['citric_acid'].hist(bins=10,color = 'red')
plt.show()

# %%
df['residual_sugar'].hist(bins=10,color = 'green')
plt.show()

# %%
df['Chlorides'].hist(bins=10,color= 'yellow')
plt.show()

# %%
df['free_sulfur_dioxide'].hist(bins=10)
plt.show()

# %%
df['total_sulfur_dioxide'].hist(bins=10,color='pink')
plt.show()

# %%
df['Density'].hist(bins=10,color = 'grey')
plt.show()

# %%
df['pH'].hist(bins=10,color = 'purple')
plt.show()

# %%
df['Sulphates'].hist(bins=10,color = 'brown')
plt.show()

# %%
df['Alcohol'].hist(bins=10,color='maroon')
plt.show()

# %%
df['Quality'].hist(bins=10,color= 'cyan')
plt.show()

# %%
plt.scatter(df['Chlorides'],df['free_sulfur_dioxide'],color = 'red')
plt.show()

# %%
plt.scatter(df['fixed_acidity'],df['volatile_acidity'])
plt.show()

# %%
plt.scatter(df['Sulphates'],df['Alcohol'],color= 'green')
plt.show()

# %%
plt.scatter(df['pH'],df['Alcohol'],color= 'yellow')
plt.show()

# %%
df.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.929586     0.995647
# volatile_acidity          -0.929586          1.000000    -0.959460
# citric_acid                0.995647         -0.959460     1.000000
# residual_sugar            -0.454780          0.748740    -0.532629
# Chlorides                 -0.506912          0.776111    -0.577235
# free_sulfur_dioxide        0.076475          0.286367    -0.016531
# total_sulfur_dioxide       0.385191         -0.020242     0.300770
# Density                    0.599054         -0.833068     0.661225
# pH                        -0.605934          0.286543    -0.538102
# Sulphates                 -0.345236          0.651162    -0.422043
# Alcohol                    0.431511         -0.114960     0.364986
# Quality                    0.994352         -0.958002     0.997629
#
#                       residual_sugar  Chlorides  free_sulfur_dioxide  \
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df['Quality'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='Quality'>

# %%
df['pH'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='pH'>

# %%
df['citric_acid'].value_counts().plot(kind='pie', figsize=(6,6))
# Out:
# <Axes: ylabel='citric_acid'>
