# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sb

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df  = df.drop_duplicates()

# %%
df  = df.dropna()

# %%
df.describe()
# Out:
#        Fixed Acidity  Volatile Acidity  Citric Acid  Residual Sugar  \
# count       4.000000           4.00000     4.000000        4.000000
# mean        8.550000           0.65500     0.150000        2.175000
# std         1.776701           0.26096     0.273983        0.340343
# min         7.400000           0.28000     0.000000        1.900000
# 25%         7.700000           0.59500     0.000000        1.900000
# 50%         7.800000           0.73000     0.020000        2.100000
# 75%         8.650000           0.79000     0.170000        2.375000
# max        11.200000           0.88000     0.560000        2.600000
#
#        Chlorides  Free Sulfur Dioxide  Total Sulfur Dioxide   Density  \
# count   4.000000             4.000000              4.000000  4.000000
# mean    0.085250            17.000000             53.750000  0.997400
# std     0.011529             5.887841             14.198005  0.000589
# min     0.075000            11.000000             34.000000  0.996800
# ...

# %%
'STATISTICS WITH RESPECT TO COLUMNS'
# Out:
# 'STATISTICS WITH RESPECT TO COLUMNS'

# %%
df[['Fixed Acidity','Alcohol','Volatile Acidity','Citric Acid','Residual Sugar','Chlorides','Density','pH','Sulphates','Quality']].describe()
# Out:
#        Fixed Acidity  Alcohol  Volatile Acidity  Citric Acid  Residual Sugar  \
# count       4.000000      4.0           4.00000     4.000000        4.000000
# mean        8.550000      9.7           0.65500     0.150000        2.175000
# std         1.776701      0.2           0.26096     0.273983        0.340343
# min         7.400000      9.4           0.28000     0.000000        1.900000
# 25%         7.700000      9.7           0.59500     0.000000        1.900000
# 50%         7.800000      9.8           0.73000     0.020000        2.100000
# 75%         8.650000      9.8           0.79000     0.170000        2.375000
# max        11.200000      9.8           0.88000     0.560000        2.600000
#
#        Chlorides   Density        pH  Sulphates  Quality
# count   4.000000  4.000000  4.000000   4.000000     4.00
# mean    0.085250  0.997400  3.282500   0.617500     5.25
# std     0.011529  0.000589  0.157136   0.056789     0.50
# ...

# %%
'Highest rated wine has alcohol content of',df['Alcohol'].max()
# Out:
# ('Highest rated wine has alcohol content of', 9.8)

# %%
'Lowest rated wine has alcohol content of',df['Alcohol'].min()
# Out:
# ('Lowest rated wine has alcohol content of', 9.4)
